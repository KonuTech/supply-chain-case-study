# %%
# https://pypi.org/project/PuLP/
# https://coin-or.github.io/pulp/guides/index.html

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
import json
import pandas as pd
from sqlite3 import connect

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
# Get the absolute path of the file within the INPUTS directory
file_path = os.path.join(os.getcwd(), 'INPUTS', 'case_study_data.csv')

# Print the file path
print(file_path)
# Out:
# C:\Users\KonuTech\PycharmProjects\supply-chain-case-study\INPUTS\case_study_data.csv

# %%
# Get the absolute path of the config within the CONFIGS directory
config_path = os.path.join(os.getcwd(), 'CONFIGS', 'config.json')

# Print the fileconfig_pathpath
print(config_path)
# Out:
# C:\Users\KonuTech\PycharmProjects\supply-chain-case-study\CONFIGS\config.json

# %%
with open(config_path, encoding='utf-8') as f:
    CONFIG = json.load(f)

# %%
INDEX_COL = CONFIG["INPUTS"]["INDEX_COLUMNS"]
SEP = CONFIG["INPUTS"]["SEPARATOR"]
DECIMAL = CONFIG["INPUTS"]["DECIMAL"]
ENCODING = CONFIG["INPUTS"]["ENCODING"]
DATE_COLUMNS = CONFIG["INPUTS"]["DATE_COLUMNS"]
FLOAT_PRECISION = CONFIG["INPUTS"]["FLOAT_PRECISION"]
DTYPE = CONFIG["INPUTS"]["DTYPE"]
COLUMNS_WITH_NAN_VALUES = CONFIG["INPUTS"]["COLUMNS_WITH_NAN_VALUES"]

# %%
df = pd.read_csv(
    file_path,
#     index_col=INDEX_COL,
    sep=SEP,
    encoding=ENCODING,
    engine="c",
    low_memory=False,
    parse_dates=DATE_COLUMNS,
    dtype=DTYPE
)

# %% [markdown]
# # PREPROCESSING

# %%
# Use regex to separate the string parts of the Order ID column into separate fields
df[['Order ID prefix', 'Order ID year', 'Order ID number']] = df['Order ID'].str.extract(r'(\w+)-(\d+)-(\d+)')

# Use regex to separate the string parts of the Order Date column into separate fields
df[['Order Year', 'Order Month', 'Order Day']] = pd.to_datetime(df['Order Date']).dt.strftime('%Y-%m-%d').str.extract(r'(\d{4})-(\d{2})-(\d{2})')

# %% [markdown]
# # SQL

# %%
conn = connect(':memory:')
df.to_sql('data', conn)
# Out:
# 9993

# %%
pd.read_sql(
"""
    SELECT
        *
    FROM data
""",
conn
)
# Out:
#       index        Order ID           Order Date     Ship Mode Region  \
# 0         0  PL-2015-110870  2015-12-12 00:00:00   First Class   West
# 1         1  PL-2015-110870  2015-12-12 00:00:00   First Class   West
# 2         2  PL-2014-143210  2014-12-01 00:00:00   First Class   East
# 3         3  PL-2014-143210  2014-12-01 00:00:00   First Class   East
# 4         4  PL-2014-143210  2014-12-01 00:00:00   First Class   East
# ...     ...             ...                  ...           ...    ...
# 9988   9988  SL-2015-165743  2015-11-20 00:00:00  Second Class   West
# 9989   9989  SL-2017-105998  2017-11-03 00:00:00   First Class   West
# 9990   9990  SL-2017-105998  2017-11-03 00:00:00   First Class   West
# 9991   9991  SL-2014-148194  2014-05-04 00:00:00   First Class   West
# 9992   9992  SL-2014-148194  2014-05-04 00:00:00   First Class   West
#
#            Product ID         Category Sub-Category  \
# 0     TEC-AC-10002926       Technology  Accessories
# 1     OFF-SU-10001225  Office Supplies     Supplies
# 2     TEC-PH-10004434       Technology       Phones
# 3     FUR-FU-10003878        Furniture  Furnishings
# 4     FUR-FU-10002268        Furniture  Furnishings
# ...               ...              ...          ...
# 9988  OFF-BI-10001758  Office Supplies      Binders
# 9989  TEC-AC-10004469       Technology  Accessories
# 9990  FUR-TA-10001095        Furniture       Tables
# 9991  FUR-FU-10001852        Furniture  Furnishings
# 9992  OFF-AP-10000696  Office Supplies   Appliances
#
#                                            Product Name   Sales  Quantity  \
# 0                 Logitech Wireless Marathon Mouse M705  299.94         6
# 1                                        Staple remover   25.76         7
# 2           Cisco IP Phone 7961G VoIP phone - Dark gray  271.90         2
# 3                    Linden 10" Round Wall Clock, Black   45.84         3
# 4                                 Ultra Door Push Plate    9.82         2
# ...                                                 ...     ...       ...
# 9988  Wilson Jones 14 Line Acrylic Coated Pressboard...    9.61         6
# 9989                     Microsoft Sculpt Comfort Mouse  199.75         5
# 9990                 Chromcraft Round Conference Tables 1673.18        12
# 9991  Eldon Regeneration Recycled Desk Accessories, ...   12.18         7
# 9992                                Holmes Odor Grabber   57.68         4
#
#       Discount  Profit Order ID prefix Order ID year Order ID number  \
# 0         0.00     NaN              PL          2015          110870
# 1         0.00     NaN              PL          2015          110870
# 2         0.00     NaN              PL          2014          143210
# 3         0.00     NaN              PL          2014          143210
# 4         0.00     NaN              PL          2014          143210
# ...        ...     ...             ...           ...             ...
# 9988      0.70   -7.37              SL          2015          165743
# 9989      0.00   87.89              SL          2017          105998
# 9990      0.20   20.91              SL          2017          105998
# 9991      0.00    3.90              SL          2014          148194
# 9992      0.00   19.03              SL          2014          148194
#
#      Order Year Order Month Order Day
# 0          2015          12        12
# 1          2015          12        12
# 2          2014          12        01
# 3          2014          12        01
# 4          2014          12        01
# ...         ...         ...       ...
# 9988       2015          11        20
# 9989       2017          11        03
# 9990       2017          11        03
# 9991       2014          05        04
# 9992       2014          05        04
#
# [9993 rows x 19 columns]

# %%
pd.read_sql(
"""
    SELECT
        "Order ID prefix"
        ,Region
        ,"Ship Mode"
        ,Category
        ,"Sub-Category"
        ,"Order Year"
        ,COUNT("Order ID") AS Count
        ,AVG("Profit") AS average
    FROM data
    WHERE
        "Order ID prefix" IN (
            'SL'
            --,'PL'
        )
    GROUP BY
        "Order ID prefix"
        ,Region
        ,"Ship Mode"
        ,Category
        ,"Sub-Category"
    --HAVING average <= 0
    ORDER BY average ASC
""",
conn
)
# Out:
#     Order ID prefix   Region       Ship Mode         Category Sub-Category  \
# 0                SL  Central     First Class  Office Supplies    Envelopes
# 1                SL  Central    Second Class  Office Supplies    Fasteners
# 2                SL     East     First Class  Office Supplies   Appliances
# 3                SL     East        Same Day  Office Supplies       Labels
# 4                SL     East        Same Day       Technology     Machines
# ..              ...      ...             ...              ...          ...
# 220              SL    South    Second Class       Technology      Copiers
# 221              SL  Central  Standard Class       Technology      Copiers
# 222              SL     West        Same Day       Technology      Copiers
# 223              SL     East  Standard Class       Technology      Copiers
# 224              SL     East  Standard Class       Technology     Machines
#
#     Order Year  Count  average
# 0         2017      1      NaN
# 1         2014      1      NaN
# 2         2015      2      NaN
# 3         2016      1      NaN
# 4         2014      1      NaN
# ..         ...    ...      ...
# 220       2017      1   629.99
# 221       2015      3   722.49
# 222       2017      1   839.99
# 223       2015      3  1225.64
# 224       2016      3  1597.02
#
# [225 rows x 8 columns]

# %%
pd.read_sql(
"""
SELECT SUM(Count) FROM (
    SELECT
        "Order ID prefix"
        ,Region
        ,"Ship Mode"
        ,Category
        ,"Sub-Category"
        ,"Order Year"
        ,COUNT("Order ID") AS Count
        ,AVG("Profit") AS average
    FROM data
    WHERE
        "Order ID prefix" IN (
            'SL'
            --,'PL'
        )
    GROUP BY
        "Order ID prefix"
        ,Region
        ,"Ship Mode"
        ,Category
        ,"Sub-Category"
    --HAVING average <= 0
    ORDER BY average ASC
    )
""",
conn
)
# Out:
#    SUM(Count)
# 0        1685

# %%
pd.read_sql(
"""
    SELECT
        "Order ID prefix"
        ,Region
        ,"Ship Mode"
        ,Category
        ,"Sub-Category"
        ,"Order Year"
        ,COUNT("Order ID") AS Count
        ,AVG("Profit") AS average
    FROM data
    WHERE
        "Order ID prefix" IN (
            'SL'
            --,'PL'
        )
    GROUP BY
        "Order ID prefix"
        ,Region
        ,"Ship Mode"
        ,Category
        ,"Sub-Category"
    HAVING average <= 0
    ORDER BY average ASC
""",
conn
)
# Out:
#    Order ID prefix   Region       Ship Mode         Category Sub-Category  \
# 0               SL    South        Same Day       Technology     Machines
# 1               SL     East     First Class       Technology     Machines
# 2               SL     East    Second Class       Technology     Machines
# 3               SL    South  Standard Class       Technology     Machines
# 4               SL  Central    Second Class        Furniture       Tables
# 5               SL    South     First Class        Furniture       Tables
# 6               SL  Central    Second Class       Technology     Machines
# 7               SL     West     First Class       Technology     Machines
# 8               SL     East        Same Day        Furniture       Tables
# 9               SL     East  Standard Class        Furniture       Tables
# 10              SL  Central    Second Class  Office Supplies   Appliances
# 11              SL     West  Standard Class        Furniture    Bookcases
# 12              SL     East  Standard Class        Furniture    Bookcases
# 13              SL     East    Second Class        Furniture       Tables
# 14              SL     West  Standard Class        Furniture       Tables
# 15              SL  Central  Standard Class        Furniture       Tables
# 16              SL     West     First Class        Furniture    Bookcases
# 17              SL     East     First Class        Furniture       Tables
# 18              SL  Central  Standard Class  Office Supplies      Binders
# 19              SL     West    Second Class        Furniture    Bookcases
# 20              SL     East    Second Class  Office Supplies      Storage
# 21              SL  Central        Same Day  Office Supplies      Binders
# 22              SL    South    Second Class        Furniture       Tables
# 23              SL  Central  Standard Class  Office Supplies   Appliances
# 24              SL  Central    Second Class        Furniture       Chairs
# 25              SL  Central  Standard Class        Furniture    Bookcases
# 26              SL    South  Standard Class  Office Supplies      Binders
# 27              SL     East    Second Class       Technology       Phones
# 28              SL     West    Second Class       Technology     Machines
# 29              SL    South  Standard Class        Furniture       Tables
# 30              SL     East        Same Day       Technology       Phones
# 31              SL  Central        Same Day  Office Supplies      Storage
# 32              SL     West     First Class        Furniture       Chairs
# 33              SL     East     First Class        Furniture    Bookcases
# 34              SL  Central    Second Class        Furniture  Furnishings
# 35              SL    South     First Class        Furniture       Chairs
# 36              SL  Central     First Class  Office Supplies      Binders
# 37              SL  Central  Standard Class        Furniture  Furnishings
# 38              SL  Central     First Class  Office Supplies      Storage
# 39              SL  Central  Standard Class        Furniture       Chairs
# 40              SL     East  Standard Class  Office Supplies     Supplies
# 41              SL     East  Standard Class       Technology       Phones
# 42              SL  Central    Second Class  Office Supplies      Binders
# 43              SL  Central        Same Day        Furniture  Furnishings
# 44              SL  Central    Second Class  Office Supplies      Storage
# 45              SL     East        Same Day  Office Supplies      Binders
# 46              SL     East    Second Class  Office Supplies      Binders
# 47              SL     East     First Class       Technology       Phones
# 48              SL     East     First Class        Furniture       Chairs
# 49              SL    South  Standard Class  Office Supplies     Supplies
# 50              SL     West  Standard Class  Office Supplies    Fasteners
# 51              SL  Central     First Class        Furniture  Furnishings
# 52              SL     East     First Class  Office Supplies     Supplies
# 53              SL     East     First Class  Office Supplies      Storage
# 54              SL     East    Second Class  Office Supplies     Supplies
# 55              SL    South    Second Class  Office Supplies      Storage
# 56              SL  Central     First Class        Furniture       Chairs
#
#    Order Year  Count  average
# 0        2017      1 -3839.99
# 1        2017      1  -935.96
# 2        2016      1  -643.71
# 3        2014      1  -572.00
# 4        2017      1  -566.56
# 5        2017      2  -422.83
# 6        2014      2  -381.00
# 7        2017      3  -316.33
# 8        2017      1  -295.98
# 9        2014     15  -219.98
# 10       2017      6  -201.56
# 11       2015      8  -193.52
# 12       2015      9  -177.52
# 13       2017      5  -162.19
# 14       2016      8  -157.29
# 15       2016     16  -135.56
# 16       2017      2  -108.00
# 17       2016      3   -91.11
# 18       2016     58   -85.98
# 19       2017      3   -75.31
# 20       2014      9   -74.65
# 21       2016      5   -62.52
# 22       2015      3   -62.13
# 23       2014     23   -59.49
# 24       2017      7   -56.73
# 25       2015     10   -52.30
# 26       2016     35   -51.27
# 27       2016      5   -49.14
# 28       2015      1   -46.00
# 29       2015      6   -43.36
# 30       2017      2   -43.35
# 31       2014      2   -39.67
# 32       2015      5   -38.78
# 33       2017      2   -37.16
# 34       2014      6   -31.94
# 35       2015      2   -28.60
# 36       2014     11   -24.72
# 37       2015     27   -23.30
# 38       2017      2   -23.12
# 39       2017     17   -20.81
# 40       2015      8   -20.67
# 41       2017     34   -19.05
# 42       2014     15   -18.68
# 43       2015      5   -17.91
# 44       2014      4   -14.89
# 45       2014      2   -14.33
# 46       2016     11   -12.56
# 47       2017      8   -11.87
# 48       2017      6    -8.53
# 49       2016      1    -4.38
# 50       2014      4    -3.41
# 51       2017      6    -2.30
# 52       2015      3    -2.19
# 53       2017      8    -2.17
# 54       2015      2    -1.31
# 55       2014      5    -0.85
# 56       2015      2    -0.33

# %%
pd.read_sql(
"""
    SELECT SUM(Count) FROM (
    SELECT
        "Order ID prefix"
        ,Region
        ,"Ship Mode"
        ,Category
        ,"Sub-Category"
        ,"Order Year"
        ,COUNT("Order ID") AS Count
        ,AVG("Profit") AS average
    FROM data
    WHERE
        "Order ID prefix" IN (
            'SL'
            --,'PL'
        )
    GROUP BY
        "Order ID prefix"
        ,Region
        ,"Ship Mode"
        ,Category
        ,"Sub-Category"
    HAVING average <= 0
    ORDER BY average ASC
    )
""",
conn
)
# Out:
#    SUM(Count)
# 0         450

# %%
pd.read_sql(
"""
    SELECT
        "Order ID prefix"
        ,Region
        ,"Ship Mode"
        ,Category
        ,"Sub-Category"
        ,"Order Year"
        ,COUNT("Order ID") AS Count
        ,AVG("Profit") AS average
    FROM data
    WHERE
        "Order ID prefix" IN (
            --'SL'
            'PL'
        )
    GROUP BY
        "Order ID prefix"
        ,Region
        ,"Ship Mode"
        ,Category
        ,"Sub-Category"
    --HAVING average <= 0
    ORDER BY average ASC
""",
conn
)
# Out:
#     Order ID prefix   Region       Ship Mode         Category Sub-Category  \
# 0                PL  Central     First Class  Office Supplies     Supplies
# 1                PL    South        Same Day        Furniture       Chairs
# 2                PL    South        Same Day        Furniture       Tables
# 3                PL    South    Second Class       Technology     Machines
# 4                PL     West        Same Day       Technology      Copiers
# ..              ...      ...             ...              ...          ...
# 260              PL    South    Second Class       Technology      Copiers
# 261              PL     West     First Class       Technology      Copiers
# 262              PL     East     First Class       Technology      Copiers
# 263              PL     East  Standard Class       Technology      Copiers
# 264              PL  Central  Standard Class       Technology      Copiers
#
#     Order Year  Count  average
# 0         2017      2      NaN
# 1         2014      1      NaN
# 2         2016      1      NaN
# 3         2016      2      NaN
# 4         2016      1      NaN
# ..         ...    ...      ...
# 260       2017      2   764.99
# 261       2017      5   828.36
# 262       2014      5  1089.25
# 263       2014      8  1403.59
# 264       2015      8  1715.82
#
# [265 rows x 8 columns]

# %%
pd.read_sql(
"""
    SELECT SUM(Count) FROM (
    SELECT
        "Order ID prefix"
        ,Region
        ,"Ship Mode"
        ,Category
        ,"Sub-Category"
        ,"Order Year"
        ,COUNT("Order ID") AS Count
        ,AVG("Profit") AS average
    FROM data
    WHERE
        "Order ID prefix" IN (
            --'SL'
            'PL'
        )
    GROUP BY
        "Order ID prefix"
        ,Region
        ,"Ship Mode"
        ,Category
        ,"Sub-Category"
    --HAVING average <= 0
    ORDER BY average ASC
    )
""",
conn
)
# Out:
#    SUM(Count)
# 0        8308

# %%
pd.read_sql(
"""
    SELECT
        "Order ID prefix"
        ,Region
        ,"Ship Mode"
        ,Category
        ,"Sub-Category"
        ,"Order Year"
        ,COUNT("Order ID") AS Count
        ,AVG("Profit") AS average
    FROM data
    WHERE
        "Order ID prefix" IN (
            --'SL'
            'PL'
        )
    GROUP BY
        "Order ID prefix"
        ,Region
        ,"Ship Mode"
        ,Category
        ,"Sub-Category"
    HAVING average <= 0
    ORDER BY average ASC
""",
conn
)
# Out:
#    Order ID prefix   Region       Ship Mode         Category Sub-Category  \
# 0               PL     East     First Class       Technology     Machines
# 1               PL  Central  Standard Class       Technology     Machines
# 2               PL    South  Standard Class       Technology     Machines
# 3               PL     East    Second Class        Furniture       Tables
# 4               PL  Central    Second Class        Furniture    Bookcases
# 5               PL     East    Second Class  Office Supplies     Supplies
# 6               PL     East        Same Day        Furniture       Tables
# 7               PL     East  Standard Class        Furniture       Tables
# 8               PL     West  Standard Class       Technology     Machines
# 9               PL  Central     First Class        Furniture       Tables
# 10              PL     East     First Class        Furniture       Tables
# 11              PL  Central        Same Day        Furniture       Chairs
# 12              PL  Central    Second Class        Furniture       Tables
# 13              PL  Central  Standard Class  Office Supplies     Supplies
# 14              PL  Central     First Class        Furniture    Bookcases
# 15              PL  Central        Same Day        Furniture  Furnishings
# 16              PL  Central    Second Class        Furniture  Furnishings
# 17              PL    South    Second Class  Office Supplies     Supplies
# 18              PL     West  Standard Class        Furniture       Tables
# 19              PL    South    Second Class  Office Supplies      Binders
# 20              PL    South  Standard Class        Furniture       Tables
# 21              PL  Central  Standard Class  Office Supplies   Appliances
# 22              PL  Central     First Class  Office Supplies   Appliances
# 23              PL     East  Standard Class        Furniture    Bookcases
# 24              PL     West  Standard Class        Furniture    Bookcases
# 25              PL     West     First Class        Furniture    Bookcases
# 26              PL  Central     First Class        Furniture  Furnishings
# 27              PL  Central  Standard Class        Furniture  Furnishings
# 28              PL     West  Standard Class  Office Supplies     Supplies
# 29              PL  Central     First Class  Office Supplies      Binders
# 30              PL  Central  Standard Class        Furniture    Bookcases
# 31              PL    South     First Class  Office Supplies      Binders
#
#    Order Year  Count  average
# 0        2016      7  -402.26
# 1        2014     11  -175.10
# 2        2016      9  -135.49
# 3        2016     11  -134.69
# 4        2016      8  -119.54
# 5        2014     10  -117.64
# 6        2017      8  -113.64
# 7        2016     30  -110.78
# 8        2015     23  -110.38
# 9        2017     10  -101.26
# 10       2017      7   -90.07
# 11       2016      5   -64.44
# 12       2017      8   -63.54
# 13       2017     16   -53.99
# 14       2017     14   -43.14
# 15       2017     10   -41.93
# 16       2015     38   -38.63
# 17       2016      7   -29.44
# 18       2016     57   -23.19
# 19       2016     40   -20.59
# 20       2016     24   -20.26
# 21       2014     60   -15.99
# 22       2017     12   -12.49
# 23       2017     30   -10.17
# 24       2015     35    -9.39
# 25       2014     15    -9.02
# 26       2015     19    -8.47
# 27       2016     94    -7.12
# 28       2015     40    -5.64
# 29       2015     39    -3.74
# 30       2016     17    -3.22
# 31       2015     30    -0.20

# %%
pd.read_sql(
"""
    SELECT SUM(Count) FROM (
    SELECT
        "Order ID prefix"
        ,Region
        ,"Ship Mode"
        ,Category
        ,"Sub-Category"
        ,"Order Year"
        ,COUNT("Order ID") AS Count
        ,AVG("Profit") AS average
    FROM data
    WHERE
        "Order ID prefix" IN (
            --'SL'
            'PL'
        )
    GROUP BY
        "Order ID prefix"
        ,Region
        ,"Ship Mode"
        ,Category
        ,"Sub-Category"
    HAVING average <= 0
    ORDER BY average ASC
    )
""",
conn
)
# Out:
#    SUM(Count)
# 0         744

# %%
pd.read_sql(
"""
    SELECT
        "Order Year"
        ,"Order Month"
        ,COUNT("Order ID") AS Count
        ,SUM("Sales") AS Sales
    FROM data
    GROUP BY
        "Order Year"
        ,"Order Month"
""",
conn
)
# Out:
#    Order Year Order Month  Count     Sales
# 0        2014          01     79  14236.89
# 1        2014          02     46   4519.89
# 2        2014          03    157  55691.01
# 3        2014          04    135  28295.34
# 4        2014          05    122  23648.29
# 5        2014          06    135  34595.13
# 6        2014          07    143  33946.39
# 7        2014          08    153  27909.47
# 8        2014          09    268  81777.35
# 9        2014          10    159  31453.39
# 10       2014          11    318  78628.72
# 11       2014          12    278  69545.62
# 12       2015          01     58  18174.08
# 13       2015          02     64  11951.41
# 14       2015          03    138  38726.25
# 15       2015          04    160  34195.21
# 16       2015          05    146  30131.69
# 17       2015          06    138  24797.29
# 18       2015          07    140  28765.32
# 19       2015          08    159  36898.33
# 20       2015          09    293  64595.92
# 21       2015          10    166  31404.92
# 22       2015          11    323  75708.60
# 23       2015          12    316  74919.52
# 24       2016          01     89  18542.49
# 25       2016          02     83  22978.81
# 26       2016          03    163  51715.87
# 27       2016          04    170  38750.04
# 28       2016          05    225  56987.73
# 29       2016          06    199  40344.53
# 30       2016          07    201  39261.96
# 31       2016          08    176  31115.37
# 32       2016          09    363  73410.02
# 33       2016          10    196  59687.74
# 34       2016          11    370  79411.97
# 35       2016          12    352  96999.04
# 36       2017          01    155  43971.37
# 37       2017          02    107  20301.13
# 38       2017          03    238  58872.35
# 39       2017          04    203  36521.54
# 40       2017          05    242  44261.11
# 41       2017          06    245  52981.73
# 42       2017          07    226  45264.42
# 43       2017          08    218  63120.89
# 44       2017          09    459  87866.65
# 45       2017          10    298  77776.92
# 46       2017          11    459 118447.83
# 47       2017          12    462  83829.32
